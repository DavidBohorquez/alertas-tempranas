# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/DavidBohorquez/Hack4Edu/main/Dropout_Academic%20Success%20-%20Sheet1.csv'
df = pd.read_csv(url)

df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
df['Curricular units 2nd sem (evaluations)'].unique()
# Out:
# numpy.ndarray

# %%
pip install sweetviz

# %%
import sweetviz as sv

#EDA using Autoviz
sweet_report = sv.analyze(df)

#Saving results to HTML file
sweet_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
pip install pandas_profiling --upgrade

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df)
profile.to_widgets()
profile.to_notebook_iframe()
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df['Target'][df['Target']=='Enrolled'].count()

df.drop(df[df['Target']=='Enrolled'].index, inplace=True)

df.shape
# Out:
# (3630, 37)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

aux_df = df.copy()

aux_df['Target'] = label_encoder.fit_transform(aux_df['Target'])

aux_df['Target'].unique()
df['Target'].unique()

def norm(item):
  return (item)/(item.abs().max())

aux_df = aux_df.apply(norm)
aux_df
# Out:
#       Marital status  Application mode  Application order    Course  \
# 0           0.166667          0.298246           0.833333  0.017115
# 1           0.166667          0.263158           0.166667  0.926234
# 2           0.166667          0.017544           0.833333  0.907817
# 3           0.166667          0.298246           0.333333  0.978180
# 4           0.333333          0.684211           0.166667  0.802122
# ...              ...               ...                ...       ...
# 4419        0.166667          0.017544           1.000000  0.978180
# 4420        0.166667          0.017544           0.333333  0.978180
# 4421        0.166667          0.017544           0.166667  0.950856
# 4422        0.166667          0.017544           0.166667  0.915524
# 4423        0.166667          0.175439           0.166667  0.978180
#
#       Daytime/evening attendance  Previous qualification  \
# 0                            1.0                0.023256
# ...

# %%
import matplotlib.pyplot as plt

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler

X = aux_df.iloc[:,0:36]
y = aux_df.iloc[:,36:37]

model = ExtraTreesClassifier()
model.fit(X,y)

print(model.feature_importances_)

feat_importance = pd.Series(model.feature_importances_, index=X.columns)
feat_importance.nlargest(20).plot(kind='barh')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# [0.00429518 0.02386115 0.01232898 0.02382899 0.00416576 0.00592677
#  0.0176947  0.00261341 0.01569546 0.01506692 0.01514981 0.01645759
#  0.01902541 0.00995158 0.00146859 0.02841032 0.08790006 0.02213723
#  0.03449255 0.0226609  0.00210653 0.00814814 0.01945613 0.02293731
#  0.09437492 0.08365333 0.00569186 0.00658248 0.02155288 0.03042709
#  0.14377123 0.12888917 0.00543787 0.01523425 0.01399516 0.01461029]

# %%
import numpy as np

filtered_df = df.iloc[:,np.r_[1,3,6,8,11:13,15:20,22:26,28:32,33,-1]]

filtered_df.columns
filtered_df.shape
# Out:
# (3630, 21)

# %%
label_encoder = LabelEncoder()

filtered_df['Target'] = label_encoder.fit_transform(filtered_df['Target'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.model_selection import train_test_split

X = filtered_df.iloc[:,0:-1]
y = filtered_df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
features_train_scale = scaler.transform(X_train)
features_test_scale = scaler.transform(X_test)
X_train
features_train_scale

from sklearn.neural_network import MLPClassifier
iterations=1000
hidden_layers=[10,10,10]

mlp = MLPClassifier(hidden_layer_sizes=(hidden_layers), max_iter=iterations) 

mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=[10, 10, 10], max_iter=1000)

# %%
predicted = mlp.predict(X_test)

print('Predected value\n',predicted,'\n')
print('Real value\n',y_test.values.ravel(),'\n')
print('Score:',mlp.score(X_test, y_test))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
print("\nEvaluation: considering the confusion matrix")
print(confusion_matrix(y_test,predicted), '\n')  

cm = confusion_matrix(y_test, predicted, labels=mlp.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=mlp.classes_)
disp.plot()
plt.show()
# Out:
# Predected value
#  [1 1 0 ... 1 1 1]
#
# Real value
#  [1 0 0 ... 1 1 1]
#
# Score: 0.8138564273789649
#
# Evaluation: considering the confusion matrix
# [[274 193]
#  [ 30 701]]

# %%
import pickle

pickle.dump(mlp, open('Hack4Edu.pkl', 'wb'))

# %%
filtered_df1 = df.iloc[:,np.r_[1,3,6,12:13,15:20,22:26,28:32,33,-1]]

label_encoder = LabelEncoder()

filtered_df1['Target'] = label_encoder.fit_transform(filtered_df1['Target'])

filtered_df1.shape
filtered_df1.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# Index(['Application mode', 'Course', 'Previous qualification (grade)',
#        'Admission grade', 'Debtor', 'Tuition fees up to date', 'Gender',
#        'Scholarship holder', 'Age at enrollment',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)', 'Unemployment rate', 'Target'],
# ...

# %%
X = filtered_df1.iloc[:,0:-1]
y = filtered_df1.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

scaler = StandardScaler()
scaler.fit(X_train)
features_train_scale = scaler.transform(X_train)
features_test_scale = scaler.transform(X_test)
X_train
features_train_scale

iterations=1000
hidden_layers=[10,10,10]

mlp1 = MLPClassifier(hidden_layer_sizes=(hidden_layers), max_iter=iterations) 

mlp1.fit(X_train, y_train)

predicted = mlp1.predict(X_test)

print('Score:',mlp1.score(X_test, y_test))

print("\nEvaluation: considering the confusion matrix")
print(confusion_matrix(y_test,predicted), '\n')  

cm = confusion_matrix(y_test, predicted, labels=mlp.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=mlp.classes_)
disp.plot()
plt.show()
# Out:
# Score: 0.8171953255425709
#
# Evaluation: considering the confusion matrix
# [[262 205]
#  [ 14 717]]

# %%
pickle.dump(mlp, open('Hack4Edu_1.pkl', 'wb'))
